# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ahmedma7/FlyRank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My Lane: Search Ranking Optimization
#
# I chose this lane because improving search ranking can help identify pages that need attention and improve their visibility. This lane matches the available dataset and provides a practical machine learning problem with measurable outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ## Research Question
#
# **Question:** Which pages are most likely to lose search performance and should be improved first?
#
# **Decision:** Decide which pages should be prioritized for SEO optimization.
#
# **Action:** Update the selected pages by improving their content, titles, metadata, or other SEO elements to increase visibility.
#
# **Cost of a wrong recommendation:** If a strong page is selected, time and resources may be wasted. If a weak page is missed, it may continue losing traffic and search visibility.
#
# **Why ML can help:** Machine learning can analyze multiple signals together, such as impressions, clicks, CTR, and average position, to identify pages that may need optimization more effectively than simple manual rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# ## Quick Look at the Data
#
# I explored the starter dataset to understand whether this lane is worth investigating. The numbers below summarize the dataset and show why search ranking optimization is a useful problem to study. These observations are descriptive only and do not prove any causal relationship.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
